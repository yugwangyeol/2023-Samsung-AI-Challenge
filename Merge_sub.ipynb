# %%
import pandas as pd

# %%
sub_df = pd.read_csv('../Sub/submission_blip_imgcap.csv')
server_df = pd.read_csv('../Sub/submit_sever_v1.csv')

# %%
sub_df
# Out:
#          img_name       mos                                           comments
# 0      j00zs3u6dr  5.849587  nice capture. i like the colors and the sharpn...
# 1      ytv70so3zb  5.571544               nice use of bw. i like the softness.
# 2      ia9890oozp  5.443029  i love the mood of this photo. the red is a ni...
# 3      xsj81ypx4a  5.509005                    nice detail and good use of bw.
# 4      f23994ghlh  4.933752            nice idea, but the image is a bit soft.
# ...           ...       ...                                                ...
# 13007  ya8k1hklrg  4.605710       nice idea, but the shadow is a bit too dark.
# 13008  j59djzkvpj  5.033442                  nice use of bw. i like the grain.
# 13009  o6w8lkfdy0  5.259472                     nice use of color and texture.
# 13010  hq68sz9xf5  5.022650               i like the colors and the soft feel.
# 13011  7yq897iaoo  4.749472  i like the blur effect. it is a bit too dark f...
#
# ...

# %%
server_df
# Out:
#          img_name       mos                                           comments
# 0      j00zs3u6dr  6.083277                     nice colors and great capture.
# 1      ytv70so3zb  5.592739  nice use of bw. i like the softness of the image.
# 2      ia9890oozp  4.550256            nice image. i like the dark feel to it.
# 3      xsj81ypx4a  5.851267                   nice detail and color. good job.
# 4      f23994ghlh  5.836686   nice idea, but the image quality is not so good.
# ...           ...       ...                                                ...
# 13007  ya8k1hklrg  4.633436  i like the idea, but the image quality is not ...
# 13008  j59djzkvpj  5.859907            i like the grain and the bw. nice work.
# 13009  o6w8lkfdy0  4.703718                       i like the soft pastel feel.
# 13010  hq68sz9xf5  5.530583         i like the colors and the blur. nice work.
# 13011  7yq897iaoo  5.566143  i like the idea of this photo. the blur is a b...
#
# ...

# %%
sub_df['mos'] = server_df['mos']
sub_df
# Out:
#          img_name       mos                                           comments
# 0      j00zs3u6dr  6.083277  nice capture. i like the colors and the sharpn...
# 1      ytv70so3zb  5.592739               nice use of bw. i like the softness.
# 2      ia9890oozp  4.550256  i love the mood of this photo. the red is a ni...
# 3      xsj81ypx4a  5.851267                    nice detail and good use of bw.
# 4      f23994ghlh  5.836686            nice idea, but the image is a bit soft.
# ...           ...       ...                                                ...
# 13007  ya8k1hklrg  4.633436       nice idea, but the shadow is a bit too dark.
# 13008  j59djzkvpj  5.859907                  nice use of bw. i like the grain.
# 13009  o6w8lkfdy0  4.703718                     nice use of color and texture.
# 13010  hq68sz9xf5  5.530583               i like the colors and the soft feel.
# 13011  7yq897iaoo  5.566143  i like the blur effect. it is a bit too dark f...
#
# ...

# %%
sub_df.to_csv('../Sub/submit_v11.csv',index=False)
